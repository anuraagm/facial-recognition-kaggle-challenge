# %% [markdown]
# # **Emotion Recognition from facial data**
# This notebook is an attempt to perform the classification of emotions of people, based on their facial image data. In this regard, we will make use of the dataset of images to classify 7 different emotions, namely : **angry, disgust, fear, happy, neutral, sad** and **surprised**.

# %% [markdown]
# **First we begin by importing the relevant libraries that we will use to read the data, train with our dataset and eventually build our model.**

# %%
import tensorflow as tf 
import cv2 
import os
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import random
from tensorflow import keras
from keras import layers
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout

# %%
# If your device has a GPU only then run this
tf.config.experimental.set_memory_growth(tf.config.list_physical_devices('GPU')[0], True)

# %% [markdown]
# ###**Let us begin by having a look at the shape of our images and also have a look at the image itself to understand the data that we are working with.**###

# %%
test_image = cv2.imread("./images/train/angry/0.jpg")
print("Shape of image nd-array : ", test_image.shape)
print("Sample image to check : \n")
plt.imshow(test_image)
# Out:
# Shape of image nd-array :  (48, 48, 3)
# Sample image to check :

# %% [markdown]
# **We notice from the above image data the following information about the images :**
#
# * The images look to be black and white, however, there are 3 channels as observed in the shape of the ndarray.
#
# * The images have width of 48 X 48 pixels and this is uniform across the dataset.

# %% [markdown]
# ###**We know that image classifiers tend to perform better when we have larger images as training and testing inputs. In order to achieve this increase in size, we can increase the size of our images to 96 X 96 as this specific value will maintain the aspect ratio of our images. In addition to this, we will be benchmarking our own CNN architecture as against the ImageNet classifier. This classifier is trained on images which are of the size 96 X 96 and hence we can go with the same dimensions on our data.**###

# %%
new_image_size = 96
new_image_array = cv2.resize(test_image, (new_image_size, new_image_size), interpolation=cv2.INTER_CUBIC)
plt.imshow(new_image_array)
plt.show()

# %% [markdown]
# ###**We now notice that the image is resized however, the image seems to be blurred. In order to counter this, let us apply a sharpening operation**###

# %%
filter = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpened_image = cv2.filter2D(new_image_array, -1, filter)
plt.imshow(sharpened_image)
plt.show()

# %% [markdown]
# **We can see from this image that the enlargement and the sharpening have resulted in a much better image, which can potentially result in better results during classification.**

# %% [markdown]
# ###**Next let us encode the names of the different classes into numerical values as this will make it easier for us to run metrics on the strength of our eventual classifier.**###

# %%
class_names = []
for dirpath, dirnames, filenames in os.walk("./images/train/"):
    if len(filenames) > 0 and dirpath != "./images/train/":
        class_name = os.path.basename(dirpath)
        class_names.append(class_name)
        
label_encoder = LabelEncoder()
label_encoder.fit(class_names)
encoded_class_names = label_encoder.transform(class_names)
decoded_class_names = label_encoder.inverse_transform(encoded_class_names)

print("The encoded classes are as follows : \n")

for (class_name, class_value) in zip(decoded_class_names, encoded_class_names):
  print(class_name," : ",class_value)
# Out:
# The encoded classes are as follows :
#
# sad  :  5
# surprise  :  6
# disgust  :  1
# happy  :  3
# neutral  :  4
# fear  :  2
# angry  :  0

# %% [markdown]
# ###**Now let us prepare our data for training. To do this, let us apply our transformations for all the images in our training dataset. Then let us store all the updated image arrays into a python list.**###

# %%
training_data = []
for emotion in os.listdir("./images/train/"):
  if not emotion.startswith("."):
    path = os.path.join("./images/train",emotion)
    for image in os.listdir(path):
      image_array = cv2.imread(os.path.join(path, image))
      new_image_size = 96 
      new_image_array = cv2.resize(image_array, (new_image_size, new_image_size))
      # filter = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
      # sharpened_image = cv2.filter2D(new_image_array, -1, filter)
      training_data.append([new_image_array/255.0, label_encoder.transform([emotion])[0]])

random.shuffle(training_data)
print("Sample of the training examples : \n")
print(training_data[0])
# Out:
# Sample of the training examples :
#
# [array([[[0.63137255, 0.63137255, 0.63137255],
#         [0.69019608, 0.69019608, 0.69019608],
#         [0.80784314, 0.80784314, 0.80784314],
#         ...,
#         [0.40392157, 0.40392157, 0.40392157],
#         [0.4       , 0.4       , 0.4       ],
#         [0.4       , 0.4       , 0.4       ]],
#
#        [[0.65098039, 0.65098039, 0.65098039],
#         [0.70588235, 0.70588235, 0.70588235],
#         [0.81176471, 0.81176471, 0.81176471],
#         ...,
#         [0.40392157, 0.40392157, 0.40392157],
#         [0.4       , 0.4       , 0.4       ],
#         [0.4       , 0.4       , 0.4       ]],
#
#        [[0.69411765, 0.69411765, 0.69411765],
#         [0.73333333, 0.73333333, 0.73333333],
#         [0.81568627, 0.81568627, 0.81568627],
#         ...,
#         [0.4       , 0.4       , 0.4       ],
#         [0.40392157, 0.40392157, 0.40392157],
#         [0.40392157, 0.40392157, 0.40392157]],
#
#        ...,
#
#        [[0.42352941, 0.42352941, 0.42352941],
#         [0.41960784, 0.41960784, 0.41960784],
#         [0.41568627, 0.41568627, 0.41568627],
#         ...,
#         [0.51764706, 0.51764706, 0.51764706],
#         [0.5254902 , 0.5254902 , 0.5254902 ],
#         [0.52941176, 0.52941176, 0.52941176]],
#
#        [[0.45882353, 0.45882353, 0.45882353],
#         [0.44705882, 0.44705882, 0.44705882],
#         [0.41960784, 0.41960784, 0.41960784],
#         ...,
#         [0.51372549, 0.51372549, 0.51372549],
#         [0.52156863, 0.52156863, 0.52156863],
#         [0.52941176, 0.52941176, 0.52941176]],
#
#        [[0.4745098 , 0.4745098 , 0.4745098 ],
#         [0.45882353, 0.45882353, 0.45882353],
#         [0.42352941, 0.42352941, 0.42352941],
#         ...,
#         [0.50980392, 0.50980392, 0.50980392],
#         [0.52156863, 0.52156863, 0.52156863],
#         [0.52941176, 0.52941176, 0.52941176]]]), 5]

# %%
testing_data = []
for emotion in os.listdir("./images/validation/"):
  if not emotion.startswith("."):
    path = os.path.join("./images/validation/",emotion)
    for image in os.listdir(path):
      image_array = cv2.imread(os.path.join(path, image))
      new_image_size = 96 
      new_image_array = cv2.resize(image_array, (new_image_size, new_image_size))
      # filter = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
      # sharpened_image = cv2.filter2D(new_image_array, -1, filter)
      testing_data.append([new_image_array/255.0, label_encoder.transform([emotion])[0]])

print("Sample of the training examples : \n")
print(testing_data[0])
# Out:
# Sample of the training examples :
#
# [array([[[0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.01568627, 0.01568627, 0.01568627],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.02352941, 0.02352941, 0.02352941]],
#
#        [[0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.01568627, 0.01568627, 0.01568627],
#         [0.02352941, 0.02352941, 0.02352941],
#         [0.02352941, 0.02352941, 0.02352941]],
#
#        [[0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.01568627, 0.01568627, 0.01568627],
#         [0.02352941, 0.02352941, 0.02352941],
#         [0.02745098, 0.02745098, 0.02745098]],
#
#        ...,
#
#        [[0.01568627, 0.01568627, 0.01568627],
#         [0.01568627, 0.01568627, 0.01568627],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.01568627, 0.01568627, 0.01568627],
#         [0.02352941, 0.02352941, 0.02352941],
#         [0.02352941, 0.02352941, 0.02352941]],
#
#        [[0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.01176471, 0.01176471, 0.01176471],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.02745098, 0.02745098, 0.02745098]],
#
#        [[0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.01960784, 0.01960784, 0.01960784],
#         ...,
#         [0.00784314, 0.00784314, 0.00784314],
#         [0.01960784, 0.01960784, 0.01960784],
#         [0.02745098, 0.02745098, 0.02745098]]]), 5]

# %%
X_train = []
y_train = []

for data in training_data:
    X_train.append(data[0])
    y_train.append(data[1])

X_train = np.array(X_train)
y_train = np.array(y_train)

X_test = []
y_test = []

for data in testing_data:
    X_test.append(data[0])
    y_test.append(data[1])

X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
backbone = keras.applications.ResNet50(
    input_shape=(96, 96, 3),
    include_top=False
)
model = tf.keras.Sequential([
    backbone,
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 3, 3, 2048)        23587712
#
#  conv2d_1 (Conv2D)           (None, 3, 3, 128)         2359424
#
#  global_average_pooling2d_1   (None, 128)              0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 25,964,551
# Trainable params: 25,911,431
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
history_dict = history.history
# Out:
# Epoch 1/10
# 1802/1802 [==============================] - 138s 53ms/step - loss: 1.2831 - accuracy: 0.5117 - val_loss: 1.8513 - val_accuracy: 0.3095
# Epoch 2/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 1.0818 - accuracy: 0.5916 - val_loss: 1.3192 - val_accuracy: 0.5045
# Epoch 3/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.9877 - accuracy: 0.6275 - val_loss: 1.1933 - val_accuracy: 0.5644
# Epoch 4/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.8972 - accuracy: 0.6617 - val_loss: 1.2088 - val_accuracy: 0.5652
# Epoch 5/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.7962 - accuracy: 0.6981 - val_loss: 1.2176 - val_accuracy: 0.5706
# Epoch 6/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.6866 - accuracy: 0.7422 - val_loss: 1.2687 - val_accuracy: 0.5665
# Epoch 7/10
# 1802/1802 [==============================] - 91s 51ms/step - loss: 0.5722 - accuracy: 0.7870 - val_loss: 1.3929 - val_accuracy: 0.5708
# Epoch 8/10
# 1802/1802 [==============================] - 91s 51ms/step - loss: 0.4539 - accuracy: 0.8330 - val_loss: 1.6069 - val_accuracy: 0.5430
# Epoch 9/10
# 1802/1802 [==============================] - 91s 50ms/step - loss: 0.3531 - accuracy: 0.8712 - val_loss: 1.4945 - val_accuracy: 0.5879
# Epoch 10/10
# 1802/1802 [==============================] - 91s 50ms/step - loss: 0.2813 - accuracy: 0.8959 - val_loss: 1.6583 - val_accuracy: 0.5900

# %%
plt.plot(history_dict['accuracy'])
plt.plot(history_dict['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation losses
plt.plot(history_dict['loss'])
plt.plot(history_dict['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
# Out:
# 221/221 [==============================] - 3s 11ms/step

# %%
data1_counts = [np.count_nonzero(predictions == i) for i in range(0, 7)]
data2_counts = [np.count_nonzero(y_test == i) for i in range(0, 7)]

# Set up the x-axis and bar widths
x = np.arange(0, 7)
width = 0.2

# Plot the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, data1_counts, width, color='orange', label='Predictions')
rects2 = ax.bar(x + width/2, data2_counts, width, color='blue', label='Actual')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_xlabel('Numbers')
ax.set_title('Comparison of Predictions and Actual')
ax.set_xticks(x)
ax.set_xticklabels(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
ax.legend()

plt.show()

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.53      0.47       765
#            1       0.32      0.74      0.44        47
#            2       0.37      0.46      0.41       819
#            3       0.84      0.77      0.80      1999
#            4       0.61      0.47      0.53      1577
#            5       0.42      0.46      0.44      1060
#            6       0.73      0.73      0.73       799
#
#     accuracy                           0.59      7066
#    macro avg       0.53      0.60      0.55      7066
# weighted avg       0.61      0.59      0.60      7066

# %%
for emotion in os.listdir("./images/train/"):
  if not emotion.startswith("."):
    path = os.path.join("./images/train",emotion)
    for image in os.listdir(path):
      image_array = cv2.imread(os.path.join(path, image))
      flipped_img = cv2.flip(image_array, 1)
      cv2.imwrite(os.path.join("./images/train/",emotion,"flipped_" + image), flipped_img)

# %%
training_data = []
for emotion in os.listdir("./images/train/"):
  if not emotion.startswith("."):
    path = os.path.join("./images/train",emotion)
    for image in os.listdir(path):
      image_array = cv2.imread(os.path.join(path, image))
      new_image_size = 96 
      new_image_array = cv2.resize(image_array, (new_image_size, new_image_size))
      training_data.append([new_image_array/255.0, label_encoder.transform([emotion])[0]])

random.shuffle(training_data)
print("Sample of the training examples : \n")
print(training_data[0])
# Out:
# Sample of the training examples :
#
# [array([[[0.91764706, 0.91764706, 0.91764706],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.92156863, 0.92156863, 0.92156863],
#         ...,
#         [0.90588235, 0.90588235, 0.90588235],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.92156863, 0.92156863, 0.92156863]],
#
#        [[0.91764706, 0.91764706, 0.91764706],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.92156863, 0.92156863, 0.92156863],
#         ...,
#         [0.90196078, 0.90196078, 0.90196078],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.9254902 , 0.9254902 , 0.9254902 ]],
#
#        [[0.91764706, 0.91764706, 0.91764706],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.92156863, 0.92156863, 0.92156863],
#         ...,
#         [0.89803922, 0.89803922, 0.89803922],
#         [0.91764706, 0.91764706, 0.91764706],
#         [0.92941176, 0.92941176, 0.92941176]],
#
#        ...,
#
#        [[0.8627451 , 0.8627451 , 0.8627451 ],
#         [0.8627451 , 0.8627451 , 0.8627451 ],
#         [0.86666667, 0.86666667, 0.86666667],
#         ...,
#         [0.70588235, 0.70588235, 0.70588235],
#         [0.72156863, 0.72156863, 0.72156863],
#         [0.72941176, 0.72941176, 0.72941176]],
#
#        [[0.84313725, 0.84313725, 0.84313725],
#         [0.84313725, 0.84313725, 0.84313725],
#         [0.85098039, 0.85098039, 0.85098039],
#         ...,
#         [0.70588235, 0.70588235, 0.70588235],
#         [0.7254902 , 0.7254902 , 0.7254902 ],
#         [0.73333333, 0.73333333, 0.73333333]],
#
#        [[0.83137255, 0.83137255, 0.83137255],
#         [0.83529412, 0.83529412, 0.83529412],
#         [0.84313725, 0.84313725, 0.84313725],
#         ...,
#         [0.70588235, 0.70588235, 0.70588235],
#         [0.7254902 , 0.7254902 , 0.7254902 ],
#         [0.73333333, 0.73333333, 0.73333333]]]), 5]

# %%
backbone = keras.applications.ResNet50(
    input_shape=(96, 96, 3),
    include_top=False
)
model = tf.keras.Sequential([
    backbone,
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
history_dict = history.history
# Out:
# Epoch 1/10
# 1802/1802 [==============================] - 126s 52ms/step - loss: 1.2926 - accuracy: 0.5098 - val_loss: 1.3954 - val_accuracy: 0.4808
# Epoch 2/10
# 1802/1802 [==============================] - 91s 51ms/step - loss: 1.0890 - accuracy: 0.5908 - val_loss: 1.2352 - val_accuracy: 0.5357
# Epoch 3/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.9880 - accuracy: 0.6284 - val_loss: 1.1744 - val_accuracy: 0.5576
# Epoch 4/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.9016 - accuracy: 0.6605 - val_loss: 1.1618 - val_accuracy: 0.5620
# Epoch 5/10
# 1802/1802 [==============================] - 93s 51ms/step - loss: 0.8118 - accuracy: 0.6959 - val_loss: 1.0630 - val_accuracy: 0.6226
# Epoch 6/10
# 1802/1802 [==============================] - 94s 52ms/step - loss: 0.7037 - accuracy: 0.7360 - val_loss: 1.2360 - val_accuracy: 0.5543
# Epoch 7/10
# 1802/1802 [==============================] - 94s 52ms/step - loss: 0.6017 - accuracy: 0.7771 - val_loss: 1.5265 - val_accuracy: 0.5457
# Epoch 8/10
# 1802/1802 [==============================] - 94s 52ms/step - loss: 0.4918 - accuracy: 0.8188 - val_loss: 1.4238 - val_accuracy: 0.5798
# Epoch 9/10
# 1802/1802 [==============================] - 92s 51ms/step - loss: 0.3864 - accuracy: 0.8599 - val_loss: 1.4473 - val_accuracy: 0.6134
# Epoch 10/10
# 1802/1802 [==============================] - 91s 51ms/step - loss: 0.3140 - accuracy: 0.8876 - val_loss: 1.5876 - val_accuracy: 0.6104

# %%
plt.plot(history_dict['accuracy'])
plt.plot(history_dict['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation losses
plt.plot(history_dict['loss'])
plt.plot(history_dict['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
# Out:
# 221/221 [==============================] - 3s 11ms/step

# %%
data1_counts = [np.count_nonzero(predictions == i) for i in range(0, 7)]
data2_counts = [np.count_nonzero(y_test == i) for i in range(0, 7)]

# Set up the x-axis and bar widths
x = np.arange(0, 7)
width = 0.2

# Plot the bars
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, data1_counts, width, color='orange', label='Predictions')
rects2 = ax.bar(x + width/2, data2_counts, width, color='blue', label='Actual')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_ylabel('Count')
ax.set_xlabel('Numbers')
ax.set_title('Comparison of Predictions and Actual')
ax.set_xticks(x)
ax.set_xticklabels(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
ax.legend()

plt.show()

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.48      0.52      1166
#            1       0.48      0.58      0.52        92
#            2       0.46      0.44      0.45      1047
#            3       0.81      0.84      0.82      1773
#            4       0.59      0.55      0.57      1296
#            5       0.45      0.51      0.48      1011
#            6       0.66      0.78      0.71       681
#
#     accuracy                           0.61      7066
#    macro avg       0.58      0.60      0.58      7066
# weighted avg       0.61      0.61      0.61      7066
